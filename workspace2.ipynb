# %%
from a import createDataFrame, add_mark, add_parametrs, mark_filter, parametrs_filter, group_mp, create_histogram, histogram_rendering

# %%
df = createDataFrame()
df
# Out:
#                                     absolute_path dataset_class
# 0       D:\PP_lab2\PP_lab2\dataset\zebra\0000.jpg         zebra
# 1       D:\PP_lab2\PP_lab2\dataset\zebra\0001.jpg         zebra
# 2       D:\PP_lab2\PP_lab2\dataset\zebra\0002.jpg         zebra
# 3       D:\PP_lab2\PP_lab2\dataset\zebra\0003.jpg         zebra
# 4       D:\PP_lab2\PP_lab2\dataset\zebra\0004.jpg         zebra
# ..                                            ...           ...
# 685  D:\PP_lab2\PP_lab2\dataset\bayhorse\0265.jpg      bayhorse
# 686  D:\PP_lab2\PP_lab2\dataset\bayhorse\0266.jpg      bayhorse
# 687  D:\PP_lab2\PP_lab2\dataset\bayhorse\0267.jpg      bayhorse
# 688  D:\PP_lab2\PP_lab2\dataset\bayhorse\0268.jpg      bayhorse
# 689  D:\PP_lab2\PP_lab2\dataset\bayhorse\0269.jpg      bayhorse
#
# [690 rows x 2 columns]

# %%
add_mark(df)
df
# Out:
#                                     absolute_path dataset_class  mark
# 0       D:\PP_lab2\PP_lab2\dataset\zebra\0000.jpg         zebra     1
# 1       D:\PP_lab2\PP_lab2\dataset\zebra\0001.jpg         zebra     1
# 2       D:\PP_lab2\PP_lab2\dataset\zebra\0002.jpg         zebra     1
# 3       D:\PP_lab2\PP_lab2\dataset\zebra\0003.jpg         zebra     1
# 4       D:\PP_lab2\PP_lab2\dataset\zebra\0004.jpg         zebra     1
# ..                                            ...           ...   ...
# 685  D:\PP_lab2\PP_lab2\dataset\bayhorse\0265.jpg      bayhorse     0
# 686  D:\PP_lab2\PP_lab2\dataset\bayhorse\0266.jpg      bayhorse     0
# 687  D:\PP_lab2\PP_lab2\dataset\bayhorse\0267.jpg      bayhorse     0
# 688  D:\PP_lab2\PP_lab2\dataset\bayhorse\0268.jpg      bayhorse     0
# 689  D:\PP_lab2\PP_lab2\dataset\bayhorse\0269.jpg      bayhorse     0
#
# [690 rows x 3 columns]

# %%
add_parametrs(df)
df
# Out:
#                                     absolute_path dataset_class  mark  height  \
# 0       D:\PP_lab2\PP_lab2\dataset\zebra\0000.jpg         zebra     1     320
# 1       D:\PP_lab2\PP_lab2\dataset\zebra\0001.jpg         zebra     1     320
# 2       D:\PP_lab2\PP_lab2\dataset\zebra\0002.jpg         zebra     1     320
# 3       D:\PP_lab2\PP_lab2\dataset\zebra\0003.jpg         zebra     1     320
# 4       D:\PP_lab2\PP_lab2\dataset\zebra\0004.jpg         zebra     1     300
# ..                                            ...           ...   ...     ...
# 685  D:\PP_lab2\PP_lab2\dataset\bayhorse\0265.jpg      bayhorse     0     320
# 686  D:\PP_lab2\PP_lab2\dataset\bayhorse\0266.jpg      bayhorse     0     320
# 687  D:\PP_lab2\PP_lab2\dataset\bayhorse\0267.jpg      bayhorse     0     320
# 688  D:\PP_lab2\PP_lab2\dataset\bayhorse\0268.jpg      bayhorse     0     320
# 689  D:\PP_lab2\PP_lab2\dataset\bayhorse\0269.jpg      bayhorse     0     320
#
#      width  channel
# 0      480        3
# 1      427        3
# 2      451        3
# 3      480        3
# 4      480        3
# ..     ...      ...
# 685    323        3
# 686    480        3
# 687    427        3
# 688    469        3
# 689    349        3
#
# [690 rows x 6 columns]

# %%
mark0 = mark_filter(df, 0)
mark0
# Out:
#                                     absolute_path dataset_class  mark  height  \
# 420  D:\PP_lab2\PP_lab2\dataset\bayhorse\0000.jpg      bayhorse     0     320
# 421  D:\PP_lab2\PP_lab2\dataset\bayhorse\0001.jpg      bayhorse     0     320
# 422  D:\PP_lab2\PP_lab2\dataset\bayhorse\0002.jpg      bayhorse     0     320
# 423  D:\PP_lab2\PP_lab2\dataset\bayhorse\0003.jpg      bayhorse     0     320
# 424  D:\PP_lab2\PP_lab2\dataset\bayhorse\0004.jpg      bayhorse     0     306
# ..                                            ...           ...   ...     ...
# 685  D:\PP_lab2\PP_lab2\dataset\bayhorse\0265.jpg      bayhorse     0     320
# 686  D:\PP_lab2\PP_lab2\dataset\bayhorse\0266.jpg      bayhorse     0     320
# 687  D:\PP_lab2\PP_lab2\dataset\bayhorse\0267.jpg      bayhorse     0     320
# 688  D:\PP_lab2\PP_lab2\dataset\bayhorse\0268.jpg      bayhorse     0     320
# 689  D:\PP_lab2\PP_lab2\dataset\bayhorse\0269.jpg      bayhorse     0     320
#
#      width  channel
# 420    240        3
# 421    277        3
# 422    478        3
# 423    322        3
# 424    480        3
# ..     ...      ...
# 685    323        3
# 686    480        3
# 687    427        3
# 688    469        3
# 689    349        3
#
# [270 rows x 6 columns]

# %%
mark1 = mark_filter(df, 1)
mark1
# Out:
#                                  absolute_path dataset_class  mark  height  \
# 0    D:\PP_lab2\PP_lab2\dataset\zebra\0000.jpg         zebra     1     320
# 1    D:\PP_lab2\PP_lab2\dataset\zebra\0001.jpg         zebra     1     320
# 2    D:\PP_lab2\PP_lab2\dataset\zebra\0002.jpg         zebra     1     320
# 3    D:\PP_lab2\PP_lab2\dataset\zebra\0003.jpg         zebra     1     320
# 4    D:\PP_lab2\PP_lab2\dataset\zebra\0004.jpg         zebra     1     300
# ..                                         ...           ...   ...     ...
# 415  D:\PP_lab2\PP_lab2\dataset\zebra\0415.jpg         zebra     1     320
# 416  D:\PP_lab2\PP_lab2\dataset\zebra\0416.jpg         zebra     1     320
# 417  D:\PP_lab2\PP_lab2\dataset\zebra\0417.jpg         zebra     1     320
# 418  D:\PP_lab2\PP_lab2\dataset\zebra\0418.jpg         zebra     1     320
# 419  D:\PP_lab2\PP_lab2\dataset\zebra\0419.jpg         zebra     1     320
#
#      width  channel
# 0      480        3
# 1      427        3
# 2      451        3
# 3      480        3
# 4      480        3
# ..     ...      ...
# 415    427        3
# 416    480        3
# 417    480        3
# 418    427        3
# 419    360        3
#
# [420 rows x 6 columns]

# %%
new_df = parametrs_filter(df, 0, 400, 400)
new_df
# Out:
#                                     absolute_path dataset_class  mark  height  \
# 420  D:\PP_lab2\PP_lab2\dataset\bayhorse\0000.jpg      bayhorse     0     320
# 421  D:\PP_lab2\PP_lab2\dataset\bayhorse\0001.jpg      bayhorse     0     320
# 423  D:\PP_lab2\PP_lab2\dataset\bayhorse\0003.jpg      bayhorse     0     320
# 426  D:\PP_lab2\PP_lab2\dataset\bayhorse\0006.jpg      bayhorse     0     320
# 427  D:\PP_lab2\PP_lab2\dataset\bayhorse\0007.jpg      bayhorse     0     320
# ..                                            ...           ...   ...     ...
# 678  D:\PP_lab2\PP_lab2\dataset\bayhorse\0258.jpg      bayhorse     0     320
# 680  D:\PP_lab2\PP_lab2\dataset\bayhorse\0260.jpg      bayhorse     0     320
# 684  D:\PP_lab2\PP_lab2\dataset\bayhorse\0264.jpg      bayhorse     0     320
# 685  D:\PP_lab2\PP_lab2\dataset\bayhorse\0265.jpg      bayhorse     0     320
# 689  D:\PP_lab2\PP_lab2\dataset\bayhorse\0269.jpg      bayhorse     0     320
#
#      width  channel
# 420    240        3
# 421    277        3
# 423    322        3
# 426    373        3
# 427    213        3
# ..     ...      ...
# 678    256        3
# 680    225        3
# 684    400        3
# 685    323        3
# 689    349        3
#
# [99 rows x 6 columns]

# %%
group_mp(df, 0)
# Out:
# count       270.000000
# mean     384616.888889
# std       75471.300136
# min      175680.000000
# 25%      345600.000000
# 50%      409920.000000
# 75%      447120.000000
# max      460800.000000
# Name: pixels, dtype: float64
# d:\pp_lab4\a.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pixels'] = img_pixels

# %%
histogram_rendering(df, 0)
